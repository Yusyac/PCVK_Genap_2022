# %% [markdown]
# <a href="https://colab.research.google.com/github/medekno581/PCVK_Genap_2022/blob/master/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

#Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg')
plt.imshow(img)       #Perhatikan hasilnya adalah citra dengan channel warna BGR

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB) #Konversi Channel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap='gray')

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)

#Tampilkan Plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize = (10,10)) #Ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#Perhatikan Titik Koordinat Pt1 Dan Pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(100,100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(400,400), radius=50, color=(255,0,0),  thickness=-1)
plt.imshow(black_img)

# %%
cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_COMPLEX
cv.putText(black_img, text='Hello', org=(10,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) #Nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili RGB
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2, [pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# Tugas

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap='Greens_r')

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap='GnBu_r')

# %%
img_1 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (100,100))
plt.imshow(img_1)

# %%
black_img1 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img1)

# %%
cv.circle(black_img1, center=(100,100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img1)

# %%
cv.circle(black_img1, center=(500,500), radius=50, color=(255,0,0), thickness=-1)
plt.imshow(black_img1)

# %%
cv.rectangle(black_img1,pt1=(384,510),pt2=(510,384),color=(0,255,0),thickness=10)
plt.imshow(black_img1)

# %%
cv.rectangle(black_img1,pt1=(300,300),pt2=(200,200),color=(0,255,0),thickness=10)
plt.imshow(black_img1)

# %%
cv.circle(black_img1, center=(250,250), radius=50, color=(255,0,0), thickness=-1)
plt.imshow(black_img1)

# %%
cv.line(black_img1, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_img1)

# %%
vector = cv.flip(black_img1, 0) 
#Tampilkan Plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize = (5,5)) #Ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(vector)

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB) #Konversi Channel BGR -> RGB
cv.circle(img3, center=(410,220), radius=50, color=(255,0,0), thickness=8)
plt.imshow(img3)

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB) #Konversi Channel BGR -> RGB
cv.rectangle(img3,pt1=(270,50),pt2=(500,270,), color=(255,255,255),thickness=10)
plt.imshow(img3)

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB) #Konversi Channel BGR -> RGB
cv.rectangle(img3,pt1=(10,615),pt2=(200,450), color=(255,255,255),thickness=10)
plt.imshow(img3)
